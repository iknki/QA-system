# %%
from elasticsearch import Elasticsearch


username = "elastic"
password = "w9nF5G7Pjt_lpVAcbqFy"

# 连接到 Elasticsearch，提供用户名和密码进行身份验证
es = Elasticsearch("http://127.0.0.1:9200", basic_auth=(username, password))
# 测试连接
if es.ping():
    print("Elasticsearch连接成功")
else:
    print("Elasticsearch连接失败")
# Out:
# Elasticsearch连接失败

# %%
import string
import random

def generate_random_string(length=10):
    characters = string.ascii_letters + string.digits
    return "".join(random.choice(characters) for _ in range(length))


index_name = generate_random_string()

def create_index(index_name, es):
    index_body = {
        "mappings": {
            "properties": {
                "title": {
                    "type": "text",
                    "analyzer": "ik_max_word",  # 使用ik分词器进行分词处理
                    "search_analyzer": "ik_smart"
                },
                "info": {
                    "type": "text",
                    "analyzer": "ik_max_word",  # 使用ik分词器进行分词处理
                    "search_analyzer": "ik_smart"
                }
            }
        }
    }
    es.indices.create(index = index_name, body = index_body)
    print(f"Index '{index_name}' created successfully.")

index_name ="book"
# 创建索引
create_index(index_name,es)
# Out:
# Index 'book' created successfully.

# %%
from db.ES.ESApi import ESApi
es1 = ESApi("elastic", "w9nF5G7Pjt_lpVAcbqFy")
# 上传文档
folder_path = "./data/books"
es1.load_es_offline_txt(index_name, folder_path)
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[6], line 5
#       3 # 上传文档
#       4 folder_path = "./data/books"
# ----> 5 es1.load_es_offline_txt(index_name, folder_path)
#
# File E:\PycharmProjects\问答系统\APP\db\ES\ESApi.py:70, in ESApi.load_es_offline_txt(self, index_name, folder_path)
#      68 docs = data
#      69 for doc in docs:
# ---> 70     self.es.index(index=index_name, document=doc)
#
# File E:\PycharmProjects\问答系统\.venv\lib\site-packages\elasticsearch\_sync\client\utils.py:446, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     443         except KeyError:
#     444             pass
# --> 446 return api(*args, **kwargs)
#
# File E:\PycharmProjects\问答系统\.venv\lib\site-packages\elasticsearch\_sync\client\__init__.py:2417, in Elasticsearch.index(self, index, document, body, id, error_trace, filter_path, human, if_primary_term, if_seq_no, op_type, pipeline, pretty, refresh, require_alias, routing, timeout, version, version_type, wait_for_active_shards)
#    2415 __body = document if document is not None else body
#    2416 __headers = {"accept": "application/json", "content-type": "application/json"}
# -> 2417 return self.perform_request(  # type: ignore[return-value]
#    2418     __method,
#    2419     __path,
#    2420     params=__query,
#    2421     headers=__headers,
#    2422     body=__body,
#    2423     endpoint_id="index",
#    2424     path_parts=__path_parts,
#    2425 )
#
# File E:\PycharmProjects\问答系统\.venv\lib\site-packages\elasticsearch\_sync\client\_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)
#     264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File E:\PycharmProjects\问答系统\.venv\lib\site-packages\elasticsearch\_sync\client\_base.py:352, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     349         except (ValueError, KeyError, TypeError):
#     350             pass
# --> 352     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     353         message=message, meta=meta, body=resp_body
#     354     )
#     356 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     357 if not self._verified_elasticsearch:
#     358     # If the header is set we mark the server as verified.
#
# ApiError: ApiError(500, 'null_pointer_exception', 'Cannot invoke "org.wltea.analyzer.dic.DictSegment.match(char[], int, int)" because "org.wltea.analyzer.dic.Dictionary.singleton._QuantifierDict" is null')

# %%
import json
# 索引名称
index_name = "book"

array = []


# 查询字符串
query = "周志明"

# 构建查询语句
body = {
    "query": {
        "multi_match": {
            "query": query,
            "fields": ["title", "info"]
        }
    },
    "size": 5
}

# 执行查询
results = es.search(index=index_name, body=body)

# 输出结果
print("Search results:")
for hit in results["hits"]["hits"]:
    print("title:", hit["_source"]["title"])
    print("info:", hit["_source"]["info"])
    array.append({"title":hit["_source"]["title"],"info":hit["_source"]["info"]})
    print(array)
# Out:
# Search results:
# title: 智慧的疆界
# info: title:智慧的疆界 rating:9.0 writer:周志明 translator:None pub_info: ISBN: series:None tags:人工智能
# [{'title': '智慧的疆界', 'info': 'title:智慧的疆界 rating:9.0 writer:周志明 translator:None pub_info: ISBN: series:None tags:人工智能'}]
# title: 深入理解Java虚拟机（第3版）
# info: title:深入理解Java虚拟机（第3版） rating:9.5 writer:周志明 translator:None pub_info: ISBN: series:华章原创精品 tags:JVM
# [{'title': '智慧的疆界', 'info': 'title:智慧的疆界 rating:9.0 writer:周志明 translator:None pub_info: ISBN: series:None tags:人工智能'}, {'title': '深入理解Java虚拟机（第3版）', 'info': 'title:深入理解Java虚拟机（第3版） rating:9.5 writer:周志明 translator:None pub_info: ISBN: series:华章原创精品 tags:JVM'}]
# title: 深入理解Java虚拟机（第2版）
# info: title:深入理解Java虚拟机（第2版） rating:9.0 writer:周志明 translator:None pub_info: ISBN: series:华章原创精品 tags:JVM
# [{'title': '智慧的疆界', 'info': 'title:智慧的疆界 rating:9.0 writer:周志明 translator:None pub_info: ISBN: series:None tags:人工智能'}, {'title': '深入理解Java虚拟机（第3版）', 'info': 'title:深入理解Java虚拟机（第3版） rating:9.5 writer:周志明 translator:None pub_info: ISBN: series:华章原创精品 tags:JVM'}, {'title': '深入理解Java虚拟机（第2版）', 'info': 'title:深入理解Java虚拟机（第2版） rating:9.0 writer:周志明 translator:None pub_info: ISBN: series:华章原创精品 tags:JVM'}]
# title: 忧郁的热带
# info: title:忧郁的热带 rating:9.1 writer: translator:王志明 pub_info: ISBN: series:学术前沿 tags:人类学
# [{'title': '智慧的疆界', 'info': 'title:智慧的疆界 rating:9.0 writer:周志明 translator:None pub_info: ISBN: series:None tags:人工智能'}, {'title': '深入理解Java虚拟机（第3版）', 'info': 'title:深入理解Java虚拟机（第3版） rating:9.5 writer:周志明 translator:None pub_info: ISBN: series:华章原创精品 tags:JVM'}, {'title': '深入理解Java虚拟机（第2版）', 'info': 'title:深入理解Java虚拟机（第2版） rating:9.0 writer:周志明 translator:None pub_info: ISBN: series:华章原创精品 tags:JVM'}, {'title': '忧郁的热带', 'info': 'title:忧郁的热带 rating:9.1 writer: translator:王志明 pub_info: ISBN: series:学术前沿 tags:人类学'}]
# title: 忧郁的热带
# info: title:忧郁的热带 rating:9.1 writer: translator:王志明 pub_info: ISBN: series:学术前沿 tags:人类学
# [{'title': '智慧的疆界', 'info': 'title:智慧的疆界 rating:9.0 writer:周志明 translator:None pub_info: ISBN: series:None tags:人工智能'}, {'title': '深入理解Java虚拟机（第3版）', 'info': 'title:深入理解Java虚拟机（第3版） rating:9.5 writer:周志明 translator:None pub_info: ISBN: series:华章原创精品 tags:JVM'}, {'title': '深入理解Java虚拟机（第2版）', 'info': 'title:深入理解Java虚拟机（第2版） rating:9.0 writer:周志明 translator:None pub_info: ISBN: series:华章原创精品 tags:JVM'}, {'title': '忧郁的热带', 'info': 'title:忧郁的热带 rating:9.1 writer: translator:王志明 pub_info: ISBN: series:学术前沿 tags:人类学'}, {'title': '忧郁的热带', 'info': 'title:忧郁的热带 rating:9.1 writer: translator:王志明 pub_info: ISBN: series:学术前沿 tags:人类学'}]

# %%
print("test\n\n")
# Out:
# test

# %%
from llmmodel.Prompt import Prompt

prompt = Prompt("./prompt.json").get_prompt("summary")
print(prompt)
# Out:
# 你是一名资深的知识回答助手,你总能以简练的话语回答问题，不会回答一些与知识库内容无关的东西,你需要根据知识库提供的知识作出回答,回答问题时，你只能根据给出的知识进行回答，不能自我发挥，不得擅自加入你自己的知识！！！。
# 请认真学习下列信息：
#     知识库内容：{0}
#     请注意知识库内容中，共有五组知识，每组知识包含title和info两个字段，info字段内容是你做答的依据，你需要从五组数据从选择合适的知识进行回答。
# 回答的要求是
# {{
# 1.不要自我发挥！
# 2.不能回答没有给出的内容！
# 3.不要加入你自己的知识！
# 4.你需要用简洁精炼的语言去回答问题
# }}

# %%
from db.ES.ESApi import ESApi

es = ESApi("elastic", "9YfcLUcxKiDvtzef1piK")
# 测试连接
if es.es.ping():
    print("Elasticsearch连接成功")
else:
    print("Elasticsearch连接失败")
# Out:
# Elasticsearch连接成功

# %%
import string
import random


index_name1 = es.create_index_mysql(kbname="book", info='', userid=1)
# Out:
# 知识库创建成功！
# 数据库连接已关闭。
# Index 'xjtdvptq17' created successfully.

# %%
import string
import random


index_name2 = es.create_index_mysql("law", '', 1)
# Out:
# 知识库创建成功！
# 数据库连接已关闭。
# Index '202mp6w1r6' created successfully.

# %%
# 上传文档
folder_path = "./data/books"
es.load_es_offline_txt(index_name1['kblist']['indices'], 1, folder_path)
# Out:
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# ...
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。

# %%
# 上传文档
folder_path = "./data/law"
es.load_es_offline_csv(index_name2['kblist']['indices'], 1, folder_path)
# Out:
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。
# 知识创建成功！
# 数据库连接已关闭。

# %% [markdown]
# # 测试推荐模型

# %%
from RecommendModel.RecommendModelApi import RecommendModelApi
recommendModel = RecommendModelApi('./RecommendModel/Models/')
recommendModel.load_model('modelv2')
# Out:
# e:\PycharmProjects\问答系统\.venv\lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator KMeans from version 1.4.1.post1 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
result = await recommendModel.recommend_similar_questions("可以在女方当地离婚吗")
print(result)
# Out:
# ['可以在女方当地离婚吗', '一方有残疾可以离婚吗', '如果离婚证掉了，可以离婚吗', '分裂症病史，可以直接判离婚吗', '处于忧郁症期间的人可以离婚吗', '女方婚前有抑郁症，女方可以起诉离婚吗', '女方要离婚需要抚养孩子吗', '重组家庭离婚女方可以分房产吗', '离婚，孩子可以分到财产吗', '离婚需要双方户口本吗']
# C:\Users\15849\AppData\Local\Temp\ipykernel_18364\1928382506.py:1: RuntimeWarning: coroutine 'RecommendModelApi.recommend_similar_questions' was never awaited
#   result = await recommendModel.recommend_similar_questions("可以在女方当地离婚吗")
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
from RecommendModel.RecommendModelApi import RecommendModelApi
import pandas as pd

recommendModel = RecommendModelApi("./RecommendModel/Models/")
# 读取CSV数据集
df = pd.read_csv("./data/law/law1.csv")
# 获取问题title列
questions = df['title'].tolist()
recommendModel.train_model(questions, "modelv3")
# Out:
# Epoch 1/10, Loss: 0.40935308532906056
# Epoch 2/10, Loss: 0.33680148989136455
# Epoch 3/10, Loss: 0.3351973156781623
# Epoch 4/10, Loss: 0.3342691065374771
# Epoch 5/10, Loss: 0.3335542619078978
# Epoch 6/10, Loss: 0.3329023840831734
# Epoch 7/10, Loss: 0.33227811899400295
# Epoch 8/10, Loss: 0.3316962744857036
# Epoch 9/10, Loss: 0.331171415005511
# Epoch 10/10, Loss: 0.33069513555158647

# %% [markdown]
# ### 测试config

# %%
from config.config import Config
config = Config('./config.yaml')
print(config.config['llm'])
# Out:
# {'APPID': '508af837', 'APISecret': 'ZTNkZjBkMmQwNzY0ZDVlNjkxZjBhNjY4', 'APIKey': '3df6675e31e2480676984973fb4965db', 'URL': 'ws(s)://spark-api.xf-yun.com/v3.5/chat', 'Domain': 'generalV3.5'}
